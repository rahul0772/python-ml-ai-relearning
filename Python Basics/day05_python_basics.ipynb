# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul0772/python-ml-ai-relearning/blob/main/Python%20Basics/day05_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### A Dictionary in a Dictionary

# %%
users = {
    "aeinstein" : {
        "first" : "albert",
        "last" : "eins",
        "location" : "princeton",
},
    "mcurie" : {
        "first" : "marie",
        "last" : "curie",
        "location" : "paris",
    },
}

for username, user_info in users.items():
  print("\nUsername: " + username)
  full_name = user_info['first'] + " " + user_info["last"]
  location = user_info["location"]

  print('\nFull name:' + full_name.title())
  print('\tlocation: ' + location.title())
# Out:
# Username: aeinstein
#
# Full name:Albert Eins
# 	location: Princeton
#
# Username: mcurie
#
# Full name:Marie Curie
# 	location: Paris
