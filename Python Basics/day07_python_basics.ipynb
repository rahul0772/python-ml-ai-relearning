# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul0772/python-ml-ai-relearning/blob/main/Python%20Basics/day07_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Removing All Instances of Specific Values from a List

# %%
pets = ["dogs", "cat", "dog", "cat", "rabbit","goldfish" , "dogs"]
print(pets)

while "cat" in pets:
  pets.remove("cat")

print(pets)
# Out:
# ['dogs', 'cat', 'dog', 'cat', 'rabbit', 'goldfish', 'dogs']
# ['dogs', 'dog', 'rabbit', 'goldfish', 'dogs']

# %%
# filling a dictonary with user input

responses = {}

# set flag to indicate that polling is active
polling_active = True

while polling_active:
  # prompt for the person's name and response
  name = input('\nwhat is your name ')
  response = input("which mountain climb ")

  # store the response in the dictionary
  responses[name] = response

  # find out if anyone else is going to take the poll
  repeat = input("would you like to let another person respond? yes or no" )
  if repeat == "no":
    polling_active = False

  # polling is complete. show result
  print("\n --- Poll Results ---")
  for name, response in responses.items():
    print(name + " would like to climb " + response + ".")
# Out:
# what is your name Rahul
# which mountain climb IDk
# would you like to let another person respond? yes or noNo
#
#  --- Poll Results ---
# Rahul would like to climb IDk.
#
# what is your name rahul
# which mountain climb figi
# would you like to let another person respond? yes or noyes
#
#  --- Poll Results ---
# Rahul would like to climb IDk.
# rahul would like to climb figi.
#
# what is your name Rahul
# which mountain climb Himalayas
# would you like to let another person respond? yes or noYes
#
#  --- Poll Results ---
# Rahul would like to climb Himalayas.
# rahul would like to climb figi.
#
# what is your name
# which mountain climb
# would you like to let another person respond? yes or nono
#
#  --- Poll Results ---
# Rahul would like to climb Himalayas.
# rahul would like to climb figi.
#  would like to climb .

# %% [markdown]
# ##-------------------------------------------

# %% [markdown]
# # Functions

# %%
# Define a function

def greet_user():
  """display a simple greeting"""
  print("hello ")

greet_user()
# Out:
# hello

# %%
#passing information to a function

def greet_user(username):
  '''display a simple greeting'''
  print("hello, " + username.title())

greet_user("jes")
# Out:
# hello, Jes

# %%
greet_user("rahul")
# Out:
# hello, Rahul

# %%
# arguments and parameters
# username = parameter argument = rahul


# passing Argumets
## position argumets

def describe_pet(animal_type, pet_name):
  '''display information about pet'''
  print("I have a " + animal_type + ".")
  print("my " + animal_type + "'s name is " + pet_name.title())

describe_pet("hamster", "harry")
# Out:
# I have a hamster.
# my hamster's name is Harry

# %%
# multiple function calls

def describe_pet(animal_type, pet_name):
  '''display information about a pet'''
  print('i have a ' + animal_type)
  print("my " + animal_type + "'s name is " + pet_name.title())

describe_pet("hamster", "harry")
describe_pet("cat", "tom")
# Out:
# i have a hamster
# my hamster's name is Harry
# i have a cat
# my cat's name is Tom

# %%
# orders in positional args

def describe_pet(animal_type, pet_name):
  """Display information about a pet."""
  print("I have a " + animal_type + ".")
  print("My " + animal_type + "'s name is " + pet_name.title() + ".")

describe_pet("harry", "hamster")
# Out:
# I have a harry.
# My harry's name is Hamster.

# %%
# Keyword argumets :  name-value pair that you pass to a function

describe_pet(animal_type = "hamster", pet_name = "harry")
# Out:
# I have a hamster.
# My hamster's name is Harry.

# %%
#order not matter

describe_pet(animal_type = "hamster", pet_name = "harry")
describe_pet(pet_name='harry', animal_type='hamster')
# Out:
# I have a hamster.
# My hamster's name is Harry.
# I have a hamster.
# My hamster's name is Harry.

# %%
# default values

def describe_pet(pet_name, animal_type = "dog"):
  '''display information about a pet'''
  print("I have a " + animal_type)
  print("my " + animal_type + "'s name is " + pet_name.title())

describe_pet(pet_name = "tom")
# Out:
# I have a dog
# my dog's name is Tom

# %%
describe_pet("tom")
# Out:
# I have a dog
# my dog's name is Tom

# %%
# avoid arg error

def describe_pet(animal_type, pet_name):
  """Display information about a pet."""
  print("\nI have a " + animal_type + ".")
  print("My " + animal_type + "'s name is " + pet_name.title() + ".")

describe_pet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3737358603.py in <cell line: 0>()
#       6   print("My " + animal_type + "'s name is " + pet_name.title() + ".")
#       7
# ----> 8 describe_pet()
#
# TypeError: describe_pet() missing 2 required positional arguments: 'animal_type' and 'pet_name'

# %%
# return values (works for large program)

def get_formatted_name(first_name, last_name):
  '''return a full name, neat formatted'''
  full_name = first_name + ' ' + last_name
  return full_name.title()

musician = get_formatted_name("jimi", "hendrix")
print(musician)
# Out:
# Jimi Hendrix

# %%
# makin an arg optional
# original

def get_formatted_name(first_name, middle_name, last_name):
  '''return a full name, neatly formatted'''
  full_name = first_name + ' ' + middle_name + " " + last_name
  return full_name.title()

musician = get_formatted_name("john", "lee", "hooker")
print(musician)
# Out:
# John Lee Hooker

# %%
# middle name optional

def get_formatted_name(first_name, last_name, middle_name = ""):
  '''return a full name, neatly formatted'''
  if middle_name:
    full_name = first_name + " " + middle_name + " " + last_name
  else:
    full_name = first_name + " " + last_name
  return full_name.title()

musician = get_formatted_name("jimi", "hendrix")
print(musician)

musician = get_formatted_name("joh", "hooker", " lee")
print(musician)
# Out:
# Jimi Hendrix
# Joh  Lee Hooker

# %%
# returning a dictionary

def build_person(first_name, last_name):
  '''return a dictionary of information about a person'''
  person = {"first" : first_name, "last" : last_name}
  return person

musician = build_person("jimi", "hendrix")
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix'}

# %%
build_person("dr", "kel")
# Out:
# {'first': 'dr', 'last': 'kel'}

# %%
# make optional

def build_person(first_name, last_name, age = ""):
  """return a dictionary of information about a person"""
  person = {"first" : first_name, "last" : last_name}
  if age:
    person["age"] = age
  return person

musician = build_person("jimi", "hend", age  = 23)
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hend', 'age': 23}

# %%
# a function with a while loop

def get_formatted_name(first_name, last_name):
 """Return a full name, neatly formatted."""
 full_name = first_name + ' ' + last_name
 return full_name.title()
# This is an infinite loop!
while True:
 print("\nPlease tell me your name:")
 f_name = input("First name: ")
 l_name = input("Last name: ")

 formatted_name = get_formatted_name(f_name, l_name)
 print("\nHello, " + formatted_name + "!")
# Out:
# Please tell me your name:
# First name: rahul
# Last name: r
#
# Hello, Rahul R!
#
# Please tell me your name:
# First name: ra
# Last name: a
#
# Hello, Ra A!
#
# Please tell me your name:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2386916556.py in <cell line: 0>()
#       8 while True:
#       9  print("\nPlease tell me your name:")
# ---> 10  f_name = input("First name: ")
#      11  l_name = input("Last name: ")
#      12
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
# adding quit to avoid infinite loop

def get_formatted_name(first_name, last_name):
  """Return a full name, neatly formatted."""
  full_name = first_name + ' ' + last_name
  return full_name.title()

while True:
  print("\nPlease tell me your name:")
  print("(enter 'q' at any time to quit)")

  f_name = input("First name: ")
  if f_name == 'q':
    break

  l_name = input("Last name: ")
  if l_name == 'q':
    break

  formatted_name = get_formatted_name(f_name, l_name)
  print("\nHello, " + formatted_name)
# Out:
# Please tell me your name:
# (enter 'q' at any time to quit)
# First name: rahul
# Last name: r
#
# Hello, Rahul R
#
# Please tell me your name:
# (enter 'q' at any time to quit)
# First name: f
# Last name:
#
# Hello, F
#
# Please tell me your name:
# (enter 'q' at any time to quit)
# First name: asf
# Last name: sadfad
#
# Hello, Asf Sadfad
#
# Please tell me your name:
# (enter 'q' at any time to quit)
# First name: asf
# Last name: q

# %%
# passing a list

def greet_users(names):
  '''print a simple greeting to each user in the list'''
  for name in names:
    msg = "Hello, " + name.title()
    print(msg)

usernames = ["hannah", "ty", "margot"]
greet_users(usernames)
# Out:
# Hello, Hannah
# Hello, Ty
# Hello, Margot

# %%
# modifying a list in a function
# start with some design that need to be printed

unprinted_designs = ['iphone case', "robot pendant", "dod"]
completed_models = []

# simulate printing each design until none left
# move each design to completed_models after printing

while unprinted_designs:
  current_design = unprinted_designs.pop()

  # simulate creating a 3d print from the design
  print("printing model: " + current_design)
  completed_models.append(current_design)

# display all completed models
print("\nthe following models have been printed:")
for completed_model in completed_models:
  print(completed_model)
# Out:
# printing model: dod
# printing model: robot pendant
# printing model: iphone case
#
# the following models have been printed:
# dod
# robot pendant
# iphone case

# %%
# more efficient code

def print_models(unprinted_designs, completed_models):
  '''
  simulate printing each design, until none left
  move each design to completed_models after printing
  '''
  while unprinted_designs:
    current_design = unprinted_designs.pop()

    # simulate creating a 3d print from the design
    print("printing model: " + current_design)
    completed_models.append(current_design)

def show_completed_models(completed_models):
  '''show all the models that were printed'''
  print("\nthe following models have been printed:")
  for completed_model in completed_models:
    print(completed_model)

unprinted_designs = ["inphone case", "robot pendant", "dod"]
completed_models = []

print_models(unprinted_designs, completed_models)
show_completed_models(completed_models)
# Out:
# printing model: dod
# printing model: robot pendant
# printing model: inphone case
#
# the following models have been printed:
# dod
# robot pendant
# inphone case

# %%
# preventing a function from modifying a list
# passing an arbitrary number of args

def make_pizza(*toppings):
  '''print the list of toppings that have been requested'''
  print(toppings)

make_pizza("pepperoni")
make_pizza("mushroom", "green peppers", "extra cheese")
# Out:
# ('pepperoni',)
# ('mushroom', 'green peppers', 'extra cheese')

# %%
# replace the print statement with a loop that runs through the list of toppings and describes the pizza being ordered
# *toppings tells Python to make an empty tuple called toppings and pack whatever values it receives into this tuple

def make_pizza(*toppings):
  '''summarize the pizza we are about to make'''
  print("\nmaking a pizza with the following toppings: ")
  for topping in toppings:
    print("-" + topping)

make_pizza("pepperoni")
make_pizza("mushroom", "green peppers", "extra cheese")
# Out:
# making a pizza with the following toppings:
# -pepperoni
#
# making a pizza with the following toppings:
# -mushroom
# -green peppers
# -extra cheese

# %%
# mixing positional and arbitary args

def make_pizza(size, *toppings):
  '''summarize the pizza we are about to make '''
  print("\nmaking a " + str(size) +
        "-inch pizza with the following toppings: ")
  for topping in toppings:
    print("- " + topping)

make_pizza(16, "pepperoni")
make_pizza(12, "mushrooms", "green peppers", "extra cheese")
# Out:
# making a 16-inch pizza with the following toppings:
# - pepperoni
#
# making a 12-inch pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %%
# using arbitary keyword args
# double asterisks before the parameter **user_info cause Python to create an empty dictionary called user_info and pack whatever name-value pairs it receives into this dictionary

def build_profile(first, last, **user_info):
  '''build a dictionary containing everything we know about a user'''
  profile = {}
  profile["first_name"] = name
  profile["last_name"] = last
  for key, value in user_info.items():
    profile[key] = value
  return profile

user_profile = build_profile("albert", "ais", location = "goa", fields = "physics")
print(user_profile)
# Out:
# {'first_name': '', 'last_name': 'ais', 'location': 'goa', 'fields': 'physics'}

# %%
# storing functions in modules( save in pizza.py in same directory)

def make_pizza(size, *toppings):
  '''sumarize the pizza we are about to make'''
  print("making a " + str(size) + "-inch pizza with the following topings:")
  for topping in toppings:
    print("- " + topping)

# %%
import pizza

pizza.make_pizza(16, "pepporoni")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1653506373.py in <cell line: 0>()
# ----> 1 import pizza
#       2
#       3 pizza.make_pizza(16, "pepporoni")
#
# ModuleNotFoundError: No module named 'pizza'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## ------------------------------------------------------------------------------------------

# %% [markdown]
# # Classes

# %%
# class is plan/blueprint

class Dog():                                                  # define a class
  '''a simple attempt to model a dog'''                       # docstring describing what this class does

  def __init__(self, name, age)                               #  __init__() Method is just a function that belongs to a class.
  # Init always has a parameter called self, which means “this dog.”
  # The self word lets the dog remember its own information
    '''initialise name and age attribute'''                   # init runs automatically every time we create a new dog from the Dog class
    self.name = name
    self.age = age                                  # self.name = name and self.age = age save the dog’s name and age inside that dog.
    # These saved values are called attributes

  def sit(self):
    '''simulate a dog sitting in response to a command'''
    print(self.name.title() + " is now sitting")

  def roll_over(self):                                            # method sit() and roll_over() are things a dog can do
    '''simulate rilling over in response to a command'''
    print(self.name.title() + " rolled over")

# %%
"""1️⃣ Class

What it is: A plan / blueprint
Example: Dog (tells what a dog is and can do)

2️⃣ Instance (Object)

What it is: A real thing made from the class
Example:

my_dog = Dog("Tom", 3)


my_dog is one real dog

3️⃣ __init__() Method

What it does: Runs automatically when an object is created
Why used: To set up the object

def __init__(self, name, age):
    self.name = name
    self.age = age

4️⃣ self

What it means: “This object itself”
Why needed: To store and use the object’s own data

5️⃣ Attributes

What they are: Information stored in the object
Example:

self.name

self.age

Access them like:

my_dog.name
my_dog.age

6️⃣ Methods

What they are: Actions the object can do
Example:

def sit(self):
    print("The dog is sitting")


Call them like:

my_dog.sit()"""
# Out:
# '1️⃣ Class\n\nWhat it is: A plan / blueprint\nExample: Dog (tells what a dog is and can do)\n\n2️⃣ Instance (Object)\n\nWhat it is: A real thing made from the class\nExample:\n\nmy_dog = Dog("Tom", 3)\n\n\nmy_dog is one real dog\n\n3️⃣ __init__() Method\n\nWhat it does: Runs automatically when an object is created\nWhy used: To set up the object\n\ndef __init__(self, name, age):\n    self.name = name\n    self.age = age\n\n4️⃣ self\n\nWhat it means: “This object itself”\nWhy needed: To store and use the object’s own data\n\n5️⃣ Attributes\n\nWhat they are: Information stored in the object\nExample:\n\nself.name\n\nself.age\n\nAccess them like:\n\nmy_dog.name\nmy_dog.age\n\n6️⃣ Methods\n\nWhat they are: Actions the object can do\nExample:\n\ndef sit(self):\n    print("The dog is sitting")\n\n\nCall them like:\n\nmy_dog.sit()'
