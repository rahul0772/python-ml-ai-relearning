# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul0772/python-ml-ai-relearning/blob/main/Python%20Basics/day03_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dictionary

# %%
alien_0 = {'color': "green", "points": 5}

print(alien_0['color'])
print(alien_0['points']) #returns the value associated with this key
# Out:
# green
# 5

# %%
#accessing values in a dictionary

new_points = alien_0["points"]
print("U earned " + str(new_points) +  " points")
# Out:
# U earned 5 points

# %% [markdown]
# ### Adding New Key-Value Pairs

# %%
print(alien_0)

alien_0['x_position'] = 0
alien_0["y_position"] = 25
print(alien_0)
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'green', 'points': 5, 'x_position': 0, 'y_position': 25}

# %%
#new empty dictionary

alien_0 = {}

alien_0["color"] = "green"
alien_0["points"] = 5

print(alien_0)
# Out:
# {'color': 'green', 'points': 5}

# %%
#modify values in a dictionary

alien_0 = {"color" : "green"}
print("the alien color is " + alien_0["color"] + ".")

alien_0["color"] = "yellow"
print("the alien color is now " + alien_0["color"] + ".")
# Out:
# the alien color is green.
# the alien color is now yellow.

# %%
alien = {"x_position" : 0, "y_position" : 25, "speed" : "medium"}
print("original x-position: " + str(alien["x_position"]))

#move the alien to right
#determine how far to move the alien based on its current speed

if alien["speed"] == "slow":
  x_increment = 1
elif alien["speed"] == "medium":
  x_increment = 2
else:
  #this is fast
  x_increment = 3

#new position old plus increment

alien["x_position"] = alien["x_position"] + x_increment
print("new x_position: " + str(alien["x_position"]))
# Out:
# original x-position: 0
# new x_position: 2
